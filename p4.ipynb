# %% [markdown]
# Read an image, plot its histogram then do histogram equalization and comment
# about the result.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image=cv2.imread('sd.jfif',0)

# %%
plt.figure(figsize=(10,5))

# %%
plt.subplot(1,2,1)
plt.hist(image.ravel(),bins=256,color='gray')
plt.title('Original Histogram')
# Out:
# Text(0.5, 1.0, 'Original Histogram')

# %%
equalized_image=cv2.equalizeHist(image)

# %%
plt.subplot(1,2,2)
plt.hist(equalized_image.ravel(),bins=256, color='gray')
plt.title('equalized Histogram')
# Out:
# Text(0.5, 1.0, 'equalized Histogram')

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
plt.imshow(image,cmap="gray")
plt.title('original image')
plt.subplot(2,2,2)
plt.imshow(equalized_image,cmap="gray")
plt.title('equalized image')
plt.subplot(2,2,3)
plt.hist(image.ravel(),bins=256,color='gray')
plt.title('original histogram')
plt.subplot(2,2,4)
plt.hist(equalized_image.ravel(),bins=256,color="gray")
plt.title('equalized histogram')
plt.tight_layout()
plt.show()
