# %% [markdown]
# gaussian

# %%
import cv2
import numpy as np

# %%
image_path="/content/hawk.png"
image=cv2.imread(image_path)

# %%
from google.colab.patches import cv2_imshow

# %%
def gaussian_filter(image, kernel_size, sigma):
    return cv2.GaussianBlur(image, (kernel_size, kernel_size), sigma)

# Load the image
image_path = "/content/hawk.png"
image = cv2.imread(image_path)

# Apply the Gaussian filter with a kernel size of 5x5 and sigma of 0 (auto-calculated based on kernel size)
kernel_size = 5
sigma = 0
filtered_image = gaussian_filter(image, kernel_size, sigma)

# Display the original and filtered images
cv2_imshow( image)
cv2_imshow(filtered_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=445x379 at 0x7C3B9D3BB730>
# <PIL.Image.Image image mode=RGB size=445x379 at 0x7C3BD8FC20E0>
